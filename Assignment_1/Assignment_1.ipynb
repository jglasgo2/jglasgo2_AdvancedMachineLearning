# %% [markdown]
# <a href="https://colab.research.google.com/github/jglasgo2/jglasgo2_AdvancedMachineLearning/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Advanced Machine Learning
#
# Assignment 1
#
# Jeremy Glasgow
#
# Spring 2024

# %% [markdown]
# Original Code

# %%
from tensorflow.keras.datasets import imdb
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)

train_data[0]
train_labels[0]
max([max(sequence) for sequence in train_data])

word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])

import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)
# x_train[0]
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")
# Out:
# ...
# 1641221/1641221 [==============================] - 0s 0us/step

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    verbose=0, # set verbosity to 0 for cleaner output
                    validation_data=(x_val, y_val))

history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
results
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3026 - accuracy: 0.8795
# [0.30257096886634827, 0.8794800043106079]

# %% [markdown]
# **Start of assigment 1 code**

# %% [markdown]
# Using 1 hidden layer

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2910 - accuracy: 0.8815
# Loss: 0.29097047448158264
# Accuracy: 0.8814799785614014

# %% [markdown]
# Using 3 hidden layers

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2836 - accuracy: 0.8872
# Loss: 0.2836304008960724
# Accuracy: 0.8871999979019165

# %% [markdown]
# Using 32 units

# %%
model = keras.Sequential([
    layers.Dense(32, activation="relu"),
    layers.Dense(32, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2890 - accuracy: 0.8869
# Loss: 0.2890314757823944
# Accuracy: 0.8869199752807617

# %% [markdown]
# Using 64 units

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3313 - accuracy: 0.8704
# Loss: 0.3313446342945099
# Accuracy: 0.8703600168228149

# %% [markdown]
# Using 126 units

# %%
model = keras.Sequential([
    layers.Dense(126, activation="relu"),
    layers.Dense(126, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2857 - accuracy: 0.8838
# Loss: 0.28571465611457825
# Accuracy: 0.883840024471283

# %% [markdown]
# Using 8 units

# %%
model = keras.Sequential([
    layers.Dense(8, activation="relu"),
    layers.Dense(8, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2862 - accuracy: 0.8853
# Loss: 0.2862359285354614
# Accuracy: 0.8853200078010559

# %% [markdown]
# Using MSE as loss function

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss=keras.losses.MeanSquaredError(),
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0838 - accuracy: 0.8876
# Loss: 0.08381154388189316
# Accuracy: 0.8876000046730042

# %% [markdown]
# Using activation = tanh instead of relu

# %%
model = keras.Sequential([
    layers.Dense(16, activation="tanh"),
    layers.Dense(16, activation="tanh"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss='binary_crossentropy',
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=0)
results = model.evaluate(x_test, y_test)
print(f"Loss: {results[0]}")
print(f"Accuracy: {results[1]}")
# Out:
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3097 - accuracy: 0.8801
# Loss: 0.30966225266456604
# Accuracy: 0.880079984664917

# %% [markdown]
# Using Lasso/L1 Regularization to outperform on validation

# %%
from tensorflow.keras.regularizers import l1
model = keras.Sequential([
    layers.Dense(16, activation="relu", kernel_regularizer=l1(0.01)),
    layers.Dense(16, activation="relu", kernel_regularizer=l1(0.01)),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss='binary_crossentropy',
              metrics=["accuracy"])
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=100,
                    batch_size=512,
                    verbose=0, # set verbosity to 0 for cleaner output
                    validation_data=(x_val, y_val))

history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Lasso/L1 Regularization results

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# Using Ridge/L2 Regularization

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
model = keras.Sequential([
    layers.Dense(16, activation="relu", kernel_regularizer=l2(0.0001)),
    # layers.BatchNormalization(),
    # layers.Dropout(0.1),
    # layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=["accuracy"])
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    batch_size=512,
                    verbose=0, # set verbosity to 0 for cleaner output
                    validation_data=(x_val, y_val))

history_dict = history.history

# %% [markdown]
# Ridge/L2 results

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

print()

plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Summary**
#
# Using Lasso/L1 regularization, validation and train datasets performed very similarly.  Lasso shrinks the coefficients of variables to 0 where the absolute value of the coefficient is lower than other, more predictive variables.  This way, only the variables that contribute to the outcome meaningfully are used.  I used 100 epochs instead of 20 to see if more iterations helped improve the model's accuracy.  Both accuracy and loss seemed to plateau.
#
# Using Ridge/R2 regulatization, the validation set did not perform as well as the train set.  Ridge also shrinks coefficients, but Ridge does not reduce the value all the way to 0 like Lasso does.  I attempted to use BatchNormalization, a dropout layer, a third hidden layer, and added a learning rate to the optimizer.  The best performing model has a learning rate of 0.0001 and an L2 regulizer set to 0.0001. There was a clear drop off in performance between the validation and train data.  The loss is performing significantly better than the original model without any tuning.  Accuracy flat lines around the same score of 86%-87%, however the graph is much smoother than the original model.
